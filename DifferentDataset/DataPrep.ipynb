# %%
# !kaggle datasets download -d duttadebadri/identifying-different-breeds-of-snakes
# Out:
# ...
#   0%|          | 0.00/879M [00:00<?, ?B/s]
#   0%|          | 1.00M/879M [00:00<03:22, 4.54MB/s]
#   0%|          | 2.00M/879M [00:00<02:53, 5.29MB/s]
#   0%|          | 3.00M/879M [00:00<02:27, 6.23MB/s]
#   0%|          | 4.00M/879M [00:00<02:37, 5.81MB/s]
#   1%|          | 5.00M/879M [00:00<02:29, 6.13MB/s]
#   1%|          | 6.00M/879M [00:01<02:25, 6.30MB/s]
#   1%|          | 7.00M/879M [00:01<02:20, 6.52MB/s]
#   1%|          | 8.00M/879M [00:01<02:17, 6.65MB/s]
#   1%|          | 9.00M/879M [00:01<02:18, 6.60MB/s]
#   1%|          | 10.0M/879M [00:01<02:19, 6.52MB/s]
#   1%|▏         | 11.0M/879M [00:01<02:19, 6.53MB/s]
#   1%|▏         | 12.0M/879M [00:02<02:30, 6.04MB/s]
#   1%|▏         | 13.0M/879M [00:02<02:20, 6.48MB/s]
#   2%|▏         | 14.0M/879M [00:02<02:27, 6.16MB/s]
#   2%|▏         | 15.0M/879M [00:02<02:27, 6.13MB/s]
#   2%|▏         | 16.0M/879M [00:02<02:24, 6.26MB/s]
#   2%|▏         | 17.0M/879M [00:02<02:18, 6.55MB/s]
# ...

# %%
from zipfile import ZipFile
import os
for i in os.listdir('C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset'):
    if '.zip' in i:
        print(i)
        with ZipFile(i, 'r') as zipObj:
            zipObj.extractall()
        os.remove(i)
# Out:
# identifying-different-breeds-of-snakes.zip

# %%
import os
c=0
sum=0
path='C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/dataset/'
for i in os.listdir(path):
    for x in os.listdir(f'{path}/{i}'):
        c+=1
    sum+=c
    print(f'{i}: {c}')
    
    c=0
print(sum)
# Out:
# agkistrodon-contortrix: 360
# agkistrodon-piscivorus: 410
# coluber-constrictor: 385
# crotalus-atrox: 412
# crotalus-horridus: 359
# crotalus-ruber: 351
# crotalus-scutulatus: 374
# crotalus-viridis: 375
# diadophis-punctatus: 376
# haldea-striatula: 373
# heterodon-platirhinos: 395
# lampropeltis-californiae: 373
# lampropeltis-triangulum: 418
# masticophis-flagellum: 393
# natrix-natrix: 426
# nerodia-erythrogaster: 370
# nerodia-fasciata: 381
# nerodia-rhombifer: 360
# nerodia-sipedon: 370
# opheodrys-aestivus: 376
# pantherophis-alleghaniensis: 375
# pantherophis-emoryi: 329
# pantherophis-guttatus: 399
# pantherophis-obsoletus: 375
# pantherophis-spiloides: 368
# pantherophis-vulpinus: 364
# pituophis-catenifer: 371
# rhinocheilus-lecontei: 378
# storeria-dekayi: 390
# storeria-occipitomaculata: 379
# thamnophis-elegans: 370
# thamnophis-marcianus: 349
# thamnophis-proximus: 358
# thamnophis-radix: 343
# thamnophis-sirtalis: 400
# 13185

# %% [markdown]
# natrix-natrix: 426

# %%
os.mkdir('C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset')
os.mkdir('C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/natrix-natrix')
os.mkdir('C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/others')

# %%
import shutil
path='C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/dataset/'
for i in os.listdir(path):
    for x in os.listdir(f'{path}/{i}'):
        if 'pantherophis-alleghaniensis' in i:
            shutil.copy(src=f'{path}/{i}/{x}',dst='C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/natrix-natrix')
        else:
            shutil.copy(src=f'{path}/{i}/{x}',dst='C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/others')

# %%
import shutil
os.mkdir('C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/Train')

shutil.move(src=f'C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/natrix-natrix',
dst='C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/Train/')

shutil.move(src=f'C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/others/',
dst='C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/Train/')
# Out:
# 'C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/Train/others'

# %%
os.mkdir('C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/Unlocked-Challenge-Accepted/DifferentDataset/cleanDataset/scraped_images')

# %%
#Organize data for our predictions 
image_generator_submission = ImageDataGenerator(rescale=1/255) 
submission = image_generator_submission.flow_from_directory(
                                                 directory='data_cleaned/scraped_images',
                                                 shuffle=False,
                                                 target_size=(224, 224), 
                                                 class_mode=None)
